# %% [markdown]
# ## Data generation and fitting

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib notebook

# %%
# %run dataset_generator.py

# %%
def f(x):
    return np.sin(x)*x + np.cos(x) + np.log(x+0.3)*(0.2)/np.exp(x+0.3)

# %%
def basis(x,m):
    y=0
    for j in range(m+1):
        y += x**j
    return y

# %%
X,Y,t,e = dataset_generator(0,12,1e3,0,0.5**2,f)

# %%
plt.figure()
#plt.plot(X,y_pred)
plt.plot(X,Y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
y_pred,W = linear_regressor(X,t,basis,10)

# %%
plt.figure()
plt.plot(X,t,label='Data')
plt.plot(X,Y,label='Function')
plt.plot(X,y_pred.T,'--r',label='Prediction')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Model Selection
