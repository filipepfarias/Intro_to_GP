# %% [markdown]
# ## Data generation and fitting

# %%
import tensorflow_probability as tfp
import tensorflow as tf

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib notebook

# %%
# %run dataset_generator.py

# %%
no = 50

# %%
def f(x):
    pi = np.pi
    return 2*np.sin((1/6) *pi*x) #+ 1e-2*np.exp(x**0.75) + 0.5*x

# %%
def basis(x,m):
    for j in range(m):
        y = x**j
    return y

# %%
X,Y,t,e = dataset_generator(0,12,no,0,0.5**2,f)

# %%
plt.figure()
plt.plot(X,t)
plt.plot(X,Y)

# %% [markdown]
# x = X
# m = 20
# #import numpy as np
# phi = np.zeros((len(x),m))
#
# for i in range(len(x)):
#     for j in range(m):
#         #print(j)
#         phi[i][j] = x[i]**j
#         #print("\n")
#         #print("Line")
#         #print(i)

# %%
x = X
m = 5
#import numpy as np
phi = np.array([x**j for j in range(m)])
phi = np.reshape(phi.T,(len(x),m))
W = np.linalg.pinv(phi)@t
W.shape, phi.shape
# Out:
# ((5, 1), (50, 5))

# %%
w = tfp.math.pinv(phi)
w = tf.Session().run(w)@t
w.shape
# Out:
# (5, 1)

# %%
y_pred = phi@w

# %%
plt.figure()
plt.plot(X,t,'o',label='Data', markerfacecolor="None")
plt.plot(X,Y,label='Function')
plt.plot(X,y_pred,'x',label='Prediction')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Model Selection

# %% [markdown]
# We'll select the data and split the dataset.

# %%
plt.figure()
plt.plot(X,t,label='Data')
plt.plot(X,Y,label='Function')
plt.plot(X,y_pred.T,'--r',label='Prediction')
plt.axvline(4,c='k')
plt.axvline(8,c='k')
plt.legend()
# Out:
# <div id='95009e0b-c34f-4c01-b63d-7b28c12836b7'></div>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-456045a66365> in <module>()
#       2 plt.plot(X,t,label='Data')
#       3 plt.plot(X,Y,label='Function')
# ----> 4 plt.plot(X,y_pred.T,'--r',label='Prediction')
#       5 plt.axvline(4,c='k')
#       6 plt.axvline(8,c='k')
#
# c:\users\filipe farias\appdata\local\programs\python\python36\lib\site-packages\matplotlib\pyplot.py in plot(*args, **kwargs)
#    3361                       mplDeprecation)
#    3362     try:
# -> 3363         ret = ax.plot(*args, **kwargs)
#    3364     finally:
#    3365         ax._hold = washold
#
# c:\users\filipe farias\appdata\local\programs\python\python36\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1865                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1866                         RuntimeWarning, stacklevel=2)
# -> 1867             return func(ax, *args, **kwargs)
#    1868
#    1869         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# c:\users\filipe farias\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_axes.py in plot(self, *args, **kwargs)
#    1526         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1527
# -> 1528         for line in self._get_lines(*args, **kwargs):
#    1529             self.add_line(line)
#    1530             lines.append(line)
#
# c:\users\filipe farias\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_base.py in _grab_next_args(self, *args, **kwargs)
#     404                 this += args[0],
#     405                 args = args[1:]
# --> 406             for seg in self._plot_args(this, kwargs):
#     407                 yield seg
#     408
#
# c:\users\filipe farias\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     381             x, y = index_of(tup[-1])
#     382
# --> 383         x, y = self._xy_from_xy(x, y)
#     384
#     385         if self.command == 'plot':
#
# c:\users\filipe farias\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_base.py in _xy_from_xy(self, x, y)
#     240         if x.shape[0] != y.shape[0]:
#     241             raise ValueError("x and y must have same first dimension, but "
# --> 242                              "have shapes {} and {}".format(x.shape, y.shape))
#     243         if x.ndim > 2 or y.ndim > 2:
#     244             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (50, 1) and (1, 50)
