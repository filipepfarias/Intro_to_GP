# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib notebook

# %%
# %run dataset_generator.py

# %%
def f(x):
    return np.sin(x)*x + np.cos(x) + np.log(x+0.3)*(0.2)/np.exp(x+0.3)

# %%
def basis(x,i):
    for j in range(i):
        y += x**j
    return y

# %%
X,Y,t = dataset_generator(0,12,1e3,0,0.1**2,f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-f825aae957ab> in <module>()
# ----> 1 X,Y,t = dataset_generator(0,12,1e3,0,0.1**2,f)
#
# ~\git\PIBIC\bayesian_linear_regression\dataset_generator.py in dataset_generator(init, end, sample, mean, var, function)
#       9     sample = int(sample)
#      10     x = (np.array([np.linspace(init,end,sample)],dtype='int64')).T
# ---> 11     y = (function(x))
#      12     e = (np.random.normal(mean,var,sample)).T
#      13     t = y + e
#
# <ipython-input-12-a30cb8d2e09e> in f(x)
#       1 def f(x):
# ----> 2     return np.sin(x)*x + np.cos(x) + np.log(X+0.3)*(0.2)/np.exp(x+0.3)
#
# NameError: name 'X' is not defined

# %%
y_pred,W = linear_regressor(X,t,basis,10)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-118-ef20b965041f> in <module>()
# ----> 1 y_pred,W = linear_regressor(X,t,basis,10)
#
# <ipython-input-114-c863999dc171> in linear_regressor(x, t, function, m)
#       9         for j in range(m):
#      10             phi[i][j] = function(x[i],i)
# ---> 11     print(np.linalg.det(phi))
#      12
#      13     #w = ((np.linalg.inv(phi.T@phi))@phi.T)@t
#
# c:\users\filipe farias\appdata\local\programs\python\python36\lib\site-packages\numpy\linalg\linalg.py in det(a)
#    1869     a = asarray(a)
#    1870     _assertRankAtLeast2(a)
# -> 1871     _assertNdSquareness(a)
#    1872     t, result_t = _commonType(a)
#    1873     signature = 'D->D' if isComplexType(t) else 'd->d'
#
# c:\users\filipe farias\appdata\local\programs\python\python36\lib\site-packages\numpy\linalg\linalg.py in _assertNdSquareness(*arrays)
# ...

# %%
M=10

# %%
    PHI = np.zeros((len(X),M))

    for i in range(len(X)):
        for j in range(M):
            PHI[i][j] = basis(X[i],i)

    W = ((np.linalg.inv(PHI.T@PHI))@PHI.T)@t

    y_pred = W.T @ PHI.T
# Out:
# c:\users\filipe farias\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in power

# %%
plt.figure()
plt.plot(X,y_pred)
#plt.plot(X,Y)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ...
