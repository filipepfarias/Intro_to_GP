# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
n_data = 50
x = np.linspace(0,1,n_data)
X = x[0:50:5]
y = np.sin(2*np.pi*x)
y_data = np.random.normal(loc=0, scale=0.3, size=(len(X))) + y[0:50:5]
print(X.shape)
print("\n")
print(X)
print("\n")
print(x.shape)
# Out:
# (10,)
#
#
# [0.         0.10204082 0.20408163 0.30612245 0.40816327 0.51020408
#  0.6122449  0.71428571 0.81632653 0.91836735]
#
#
# (50,)

# %%
plt.figure(figsize=(10,8))
plt.plot(x,y,c='green')
plt.scatter(X,y_data,c='blue')

# %%
#Order
M = 9
M = M+1

# %%
xsum = np.zeros((1,M*2))

for i in range(M*2):
    xsum[0][i] = sum(X ** i)

# %%
S = np.zeros((M,M))
Y = np.zeros((1,M))

for i in range(M):
    for j in range(M):
        S[i][j] = xsum[0][i+j]
    Y[0][i] = sum(y_data*(X ** i))

# %%
# S * W = Y
print(S.shape)
print("\n")
print(Y.shape)

W = np.linalg.solve(S,Y.T)
W = W.T
print(W)
# Out:
# (10, 10)
#
#
# (1, 10)
# [[ 5.53117594e-01  1.51295811e+02 -3.96618574e+03  4.10369407e+04
#   -2.18701077e+05  6.67816480e+05 -1.21513182e+06  1.30197679e+06
#   -7.57894566e+05  1.84801932e+05]]

# %%
y_pred = 0

for i in range(M):
    y_pred = W[0][i]*(x**i) + y_pred

# %%
plt.figure(figsize=(10,8))
plt.plot(x,y,c='green',label='sin(2$\pi$x)')
plt.scatter(X,y_data,c='blue')
plt.plot(x[:-4],y_pred[:-4],'r--',label='Predição')
plt.legend()
