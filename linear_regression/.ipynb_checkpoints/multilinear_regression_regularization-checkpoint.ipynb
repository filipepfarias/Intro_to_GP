# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
def dataset_generator(init, end, sample, mean, var, function):
    """
    Return X,Y,t being:
    x input
    y deterministic output
    t data with noise
    """
    sample = int(sample)
    x = (np.array([np.linspace(init,end,sample)])).T
    y = (function(x))
    e = (np.array([np.random.normal(mean,var,sample)])).T
    t = y + e

    return x,y,t,e

# %%
def design_matrix(x,function,m):
    """
    Return the Phi matrix
    """  
    phi = np.zeros((len(x),m))
    mu = np.array([np.linspace(min(x),max(x),m)]).T
    for i in range(len(x)):
        for j in range(m):
            phi[i][j] = function(x[i],mu[j])    
    return phi

# %%
def fit(phi,t):
    """
    Return the model trained, i.e., W vector
    """
    w = np.linalg.pinv(phi)@t
    return w

# %%
def predict(phi,w):
    return phi@w

# %%
def split_data(x,t):
    from math import floor
    n = floor(len(x)/3)
    x_train , x_valid , x_test = x[0:n], x[n+1:2*n] , x[2*n+1:-1]
    t_train , t_valid , t_test = t[0:n], t[n+1:2*n] , t[2*n+1:-1]
    
    return x_train , x_valid , x_test, t_train , t_valid , t_test

# %%
def f_deterministic(x):
    """
    Return the deterministic function.
    """
    return 2*np.sin(np.pi*x) + 2*x

# %%
def f_basis(x,mu,s=1):
    """
    Return gaussian function with var = 1.
    """
    return np.e**(-(x-mu)**2 / s**2)

# %% [markdown]
# #### Initializing

# %%
x,y,t,e = dataset_generator(0,12,100,0,0.8**2,f_deterministic)

# %%
plt.figure();
plt.plot(x,y,label='Deterministic');
plt.plot(x,t,'o',label='Data',markerfacecolor="None");
plt.legend();
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# m = 500;
# phi = np.zeros((len(x),m))
# mu = np.array([np.linspace(min(x),max(x),m)]).T
# for i in range(len(x)):
#     for j in range(m):
#         phi[i][j] = f_basis(x[i],mu[j])
# w = np.linalg.pinv(phi)@t
# y_pred = phi@w
#
# print(x.shape,t.shape,y_pred.shape)

# %%
phi = design_matrix(x,t,f_basis,len(x))
w = fit(phi,t)
y_pred = predict(phi,w)

# %%
plt.figure();
plt.plot(x,y,label='Deterministic');
plt.plot(x,t,'o',label='Data',markerfacecolor="None");
plt.plot(x,y_pred,'+',label='Prediction',markerfacecolor="None");
plt.legend();
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x_train, x_valid, x_test, t_train, t_valid, t_test = split_data(x, t)

# %%
Error_train = [];
Error_valid = [];

x0 = np.append(x_train,x_valid)
x0 = np.reshape(x0,(len(x0),1))
t0 = np.append(t_train,t_valid)
t0 = np.reshape(t0,(len(t0),1))

for i in range(11):
    
    #Calculate train
    phi = design_matrix(x_train,f_basis,i)
    w = fit(phi,t_train)
    y_train = predict(phi,w)
    
    #Calculate validation
    phi_v = design_matrix(x0,f_basis,i)
    y_valid = predict(phi_v,w) 
    
    E_train = (sum((y_train - t_train) ** 2) / len(y_train)) ** 0.5
    E_valid = (sum((y_valid - t0) ** 2) / len(y_valid)) ** 0.5
    Error_train = np.append(Error_train,E_train)
    Error_valid = np.append(Error_valid,E_valid)
    
    #plt.figure()
    #plt.plot(x0,y_valid);

# %%
for i in range(len(Error_train)):
    if ((Error_train - Error_valid)[i]-(Error_train - Error_valid)[i-1]) < 0:
        print((Error_train - Error_valid)[i]-(Error_train - Error_valid)[i-1])
        #break
# Out:
# -0.10599943832518388
# -0.3068793813980806
# -0.3973984220622606
# -0.5215907757213021
# -4.657338275072063
# -0.4685527309574038
# -7.033148203809516
# -13.570287532738103
# -8.712768641139856

# %%
plt.figure()
plt.plot(np.arange(len(Error_valid)),Error_valid,label="Validation");
plt.plot(np.arange(len(Error_train)),Error_train,label="Train");
#plt.ylim((0,10));
plt.legend();
# Out:
# <img src="data:image/png;base64,..." width="640">
