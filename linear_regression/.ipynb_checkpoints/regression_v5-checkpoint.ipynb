# %% [markdown]
# ## Implementing the use of [pseudo-inverse](#pseudo) matrix
# known as Moore-Penrose pseudo-inverse
# $$ \Phi^{*} \equiv \left( \Phi^T \Phi \right)^{-1} \Phi^T $$

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
n_data = 50
x = np.linspace(0,1,n_data)
X = x[0:50:5]
y = np.sin(2*np.pi*x)
y_data = np.random.normal(loc=0, scale=0.3, size=(len(X))) + y[0:50:5]
print(X.shape)
print("\n")
print(X)
print("\n")
print(x.shape)
# Out:
# (10,)
#
#
# [0.         0.10204082 0.20408163 0.30612245 0.40816327 0.51020408
#  0.6122449  0.71428571 0.81632653 0.91836735]
#
#
# (50,)

# %%
plt.figure(figsize=(10,8))
plt.plot(x,y,c='green')
plt.scatter(X,y_data,c='blue')

# %%
#Order
M = 9
M = M+1

# %%
xsum = np.zeros((1,M*2))

for i in range(M*2):
    xsum[0][i] = sum(X ** i)

# %%
S = np.zeros((M,M))
Y = np.zeros((1,M))

for i in range(M):
    for j in range(M):
        S[i][j] = xsum[0][i+j]
    Y[0][i] = sum(y_data*(X ** i))

# %% [markdown]
# <a id='pseudo'>Implementing the pseudo-matrix</a>

# %%
# S * W = Y => W = S' * Y
print(S.shape)
print("\n")
print(Y.shape)

S_aux = np.dot(S,S.T) # S * S.T

S_aux = np.linalg.inv(S_aux)

S_inv = np.dot(S_aux,S.T) # S_aux * S.T

W = np.dot(Y,S_inv) # Y * S_inv

# W = np.linalg.solve(S,Y.T)
# W = W.T
print(W.shape)
print("\n")
print(W)
# Out:
# (10, 10)
#
#
# (1, 10)
# (1, 10)
#
#
# [[   0.4663609     3.17450159   57.92620406 -277.1313201   308.7117149
#     56.65651985 -150.75225359  -77.16468461   58.01738038   21.07121277]]

# %%
y_pred = 0

for i in range(M):
    y_pred = W[0][i]*(x**i) + y_pred

# %%
plt.figure(figsize=(10,8))
plt.plot(x,y,c='green',label='sin(2$\pi$x)')
plt.scatter(X,y_data,c='blue')
plt.plot(x,y_pred,'r--',label='Predict')
plt.legend()

# %% [markdown]
# ## Implement ##

# %%
print(X.shape)
print("\n")
print(y_data.shape)
# Out:
# (10,)
#
#
# (10,)

# %%
def linear_regressor(x_data, y_data, M, pseudo=False):
    M = M+1
    
    xsum = np.zeros((1,M*2))

    for i in range(M*2):
        xsum[0][i] = sum(x_data ** i)
    
    S = np.zeros((M,M))
    Y = np.zeros((1,M))

    for i in range(M):
        for j in range(M):
            S[i][j] = xsum[0][i+j]
        Y[0][i] = sum(y_data*(x_data ** i))
    
    # S * W = Y

    if pseudo == False:
        W = np.linalg.solve(S,Y.T)
        W = W.T
    else:
        S_aux = np.dot(S,S.T) # S * S.T
        S_aux = np.linalg.inv(S_aux)
        S_inv = np.dot(S_aux,S.T) # S_aux * S.T
        W = np.dot(Y,S_inv) # Y * S_inv
    
    y_pred = 0
    
    x = np.linspace(x_data[0],x_data[len(x_data)-1],50)

    for i in range(M):
        y_pred = W[0][i]*(x**i) + y_pred
    
    return y_pred

y_pred_test = linear_regressor(X,y_data,0)

# %%
print(y_pred_test.shape)
plt.plot(x,y,c='green',label='sin(2$\pi$x)')
plt.plot(np.linspace(X[0],X[len(X)-1],50),y_pred_test,'r--',label='Predict')
plt.plot(X,y_data,'o',label='Data')
plt.legend()
# Out:
# (50,)

# %%
y_pred_test = y_pred_test[0:50:5]
y_pred_test.shape
# Out:
# (10,)

# %%
L = 15

E_rms = np.zeros(L)

M_plt = np.zeros(L)

for i in range(L):
    M_plt[i] = i
    aux = linear_regressor(X,y_data,i)
    aux = aux[0:50:5]
    E_rms[i] = (sum((aux - y_data) ** 2) / len(y_pred_test)) ** 0.5

# %%
plt.plot(M_plt,E_rms, 'o--', markerfacecolor="None", ms=14)
plt.xlabel('M', fontsize=18)
plt.ylabel('$E(w)$', fontsize=18)
# Out:
# Text(0,0.5,'$E(w)$')
