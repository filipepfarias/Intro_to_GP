# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
n_data = 50
x = np.linspace(0,1,n_data)
y = np.sin(2*np.pi*x)
y_data = np.random.normal(loc=0, scale=0.3, size=n_data) + y

# %%
plt.plot(x,y,c='green')
plt.scatter(x,y_data,c='blue')

# %%
#Order
M = 3
M = 3+1

# %%
xsum = np.zeros((1,M*2))

for i in range(M*2):
    xsum[0][i] = sum(x ** i)

# %%
S = np.zeros((M,M))
Y = np.zeros((1,M))

for i in range(M):
    for j in range(M):
        S[i][j] = xsum[0][i+j]
    Y[0][i] = sum(y_data*(x ** i))

# %%
# S * W = Y
print(S.shape)
print("\n")
print(Y.shape)

W = np.linalg.solve(S,Y.T)
W = W.T
print(W)
# Out:
# (4, 4)
#
#
# (1, 4)
# [[  0.08082244   9.90521725 -30.07711769  20.30336468]]

# %%
y_pred = 0

for i in range(M):
    y_pred = W[0][i]*(x**i) + y_pred

# %%
plt.figure(figsize=(10,8))
plt.plot(x,y,c='green',label='sin(2$\pi$x)')
plt.scatter(x,y_data,c='blue')
plt.plot(x,y_pred,'r--',label='Predição')
plt.legend()
