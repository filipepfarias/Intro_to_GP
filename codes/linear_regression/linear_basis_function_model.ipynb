# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %matplotlib notebook

# %% [markdown]
# ### Generating data

# %%
sample_size = 250
x = np.array([np.linspace(0,1,sample_size) for i in range(2)])
x1, x2 = np.meshgrid(x[0],x[1])
e = np.array([np.random.normal(0,0.1**2,sample_size) for i in range(sample_size)])
y = np.sin(2*np.pi*x1)*np.sin(2*np.pi*x2) + e

x1.shape
# Out:
# (250, 250)

# %%
plt.figure(figsize=(9,7));
ax = plt.axes(projection='3d')
ax.plot_surface(x1,x2,y,cmap='plasma')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-cd7dfea159b7> in <module>()
# ----> 1 plt.figure(figsize=(9,7));
#       2 ax = plt.axes(projection='3d')
#       3 ax.plot_surface(x1,x2,y,cmap='plasma')
#
# NameError: name 'plt' is not defined

# %%
def f_phi(module,s=1):
    return np.e**(-module**2 / s**2)

# %% [markdown]
# Defining the gaussians positions

# %%
M = 10

mu1,mu2 = np.meshgrid((np.linspace(0,1,M)),(np.linspace(0,1,M)))

null = np.zeros((M,M))

fig = plt.figure(figsize=(9,7))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(mu1,mu2,null)
plt.show()

# %%
p1 = np.array([1,2,3])
p2 = np.array([2,5,4])
p1-p2
# Out:
# array([-1, -3, -1])

# %%
i=1
j=2
p1 = np.array([x1[i][j],x2[i][j]])
print(p1)

i=3
j=4
p2 = np.array([x1[i][j],x2[i][j]])
print(p2)

print(p1-p2)
# Out:
# [0.00803213 0.00401606]
# [0.01606426 0.01204819]
# [-0.00803213 -0.00803213]

# %%
mu1_r = np.reshape(mu1,M**2)
mu1_r
# Out:
# array([0.        , 0.11111111, 0.22222222, 0.33333333, 0.44444444,
#        0.55555556, 0.66666667, 0.77777778, 0.88888889, 1.        ,
#        0.        , 0.11111111, 0.22222222, 0.33333333, 0.44444444,
#        0.55555556, 0.66666667, 0.77777778, 0.88888889, 1.        ,
#        0.        , 0.11111111, 0.22222222, 0.33333333, 0.44444444,
#        0.55555556, 0.66666667, 0.77777778, 0.88888889, 1.        ,
#        0.        , 0.11111111, 0.22222222, 0.33333333, 0.44444444,
#        0.55555556, 0.66666667, 0.77777778, 0.88888889, 1.        ,
#        0.        , 0.11111111, 0.22222222, 0.33333333, 0.44444444,
#        0.55555556, 0.66666667, 0.77777778, 0.88888889, 1.        ,
#        0.        , 0.11111111, 0.22222222, 0.33333333, 0.44444444,
#        0.55555556, 0.66666667, 0.77777778, 0.88888889, 1.        ,
#        0.        , 0.11111111, 0.22222222, 0.33333333, 0.44444444,
#        0.55555556, 0.66666667, 0.77777778, 0.88888889, 1.        ,
#        0.        , 0.11111111, 0.22222222, 0.33333333, 0.44444444,
#        0.55555556, 0.66666667, 0.77777778, 0.88888889, 1.        ,
#        0.        , 0.11111111, 0.22222222, 0.33333333, 0.44444444,
#        0.55555556, 0.66666667, 0.77777778, 0.88888889, 1.        ,
#        0.        , 0.11111111, 0.22222222, 0.33333333, 0.44444444,
#        0.55555556, 0.66666667, 0.77777778, 0.88888889, 1.        ])

# %%
phi = np.zeros((sample_size,M))

for i in range(sample_size):
    for j in range(M):
        n = j
        p1 = np.array([x1[i][i],x2[i][i]])
        if j == M-1:
            n = n+j
        p2 = np.array([mu1_r[j],mu1_r[n]])
        d = np.linalg.norm(p1-p2)
        phi[i][j] = np.e**(-(d)**2 / 1**2)
phi.shape
# Out:
# (250, 10)

# %%
np.linalg.det(phi.T@phi)
# Out:
# 0.0

# %%
W = ((np.linalg.inv(phi.T@phi))@phi.T)@y
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-21-749880996a14> in <module>()
# ----> 1 W = ((np.linalg.inv(phi.T@phi))@phi.T)@y
#
# c:\users\filipe farias\appdata\local\programs\python\python36\lib\site-packages\numpy\linalg\linalg.py in inv(a)
#     526     signature = 'D->D' if isComplexType(t) else 'd->d'
#     527     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 528     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     529     return wrap(ainv.astype(result_t, copy=False))
#     530
#
# c:\users\filipe farias\appdata\local\programs\python\python36\lib\site-packages\numpy\linalg\linalg.py in _raise_linalgerror_singular(err, flag)
#      87
#      88 def _raise_linalgerror_singular(err, flag):
# ---> 89     raise LinAlgError("Singular matrix")
#      90
#      91 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix

# %%
W.shape
# Out:
# (10, 250)

# %%
y.shape
# Out:
# (250, 250)

# %%
y_pred =

# %%
y_pred = np.zeros((len(x),1))

for i in range(len(x)):
    y_pred[i][0] = sum([W[j][0]*f_phi(x[i],(1/M*j)) for j in range(M)])
# Out:
# c:\users\filipe farias\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
#
# c:\users\filipe farias\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in true_divide
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-e13e26682c6d> in <module>()
#       2
#       3 for i in range(len(x)):
# ----> 4     y_pred[i][0] = sum([W[j][0]*f_phi(x[i],(1/M*j)) for j in range(M)])
#
# ValueError: setting an array element with a sequence.
